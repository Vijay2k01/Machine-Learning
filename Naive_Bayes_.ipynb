# %% [markdown]
# # **Naive Bayes Algorithm**

# %% [markdown]
# **Importing necessary libraries**

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import pandas as pd
import seaborn as sns
import sklearn
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# %% [markdown]
# **Loading and visualising initial data**
#
# Here we have iris dataset where we classify the type of iris plant which are of three types based on the features which are petal length,width etc.

# %%
Iris = pd.read_csv('/content/Iris.csv')
Iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
sns.pairplot(Iris,hue='Species',palette=['black','orange','pink'])

# %% [markdown]
# ## **Implementing Naive Bayes**

# %%
Y = Iris['Species']
X = Iris[['SepalLengthCm', 'SepalWidthCm','PetalLengthCm', 'PetalWidthCm']]
# Test Train Splitting

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.33)

# Fitting the model
from sklearn.naive_bayes import GaussianNB
classifier = GaussianNB()
classifier.fit(X_train, Y_train)

# Making Predictions
y_pred = classifier.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
ac = accuracy_score(Y_test,y_pred)
cm = confusion_matrix(Y_test, y_pred)

# %% [markdown]
# **Evaluating the model**

# %%
print(classification_report(Y_test,Y_Pred))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       0.26      0.26      0.26        19
# Iris-versicolor       0.26      0.28      0.27        18
#  Iris-virginica       0.25      0.23      0.24        13
#
#        accuracy                           0.26        50
#       macro avg       0.26      0.26      0.26        50
#    weighted avg       0.26      0.26      0.26        50

# %%
a=Y_Pred
a=np.where(a=='Iris-setosa',1,a)
a=np.where(a=='Iris-virginica',2,a)
a=np.where(a=='Iris-versicolor',3,a)
b=Y_test
b=np.where(b=='Iris-setosa',1,b)
b=np.where(b=='Iris-virginica',2,b)
b=np.where(b=='Iris-versicolor',3,b)
sns.distplot(a, hist = False, color = 'green', label = 'Predicted Values')
sns.distplot(b, hist = False, color = 'black', label = 'Actual Values')
plt.title('Actual vs Predicted Values', fontsize = 16)
plt.xlabel('Values', fontsize = 12)
plt.ylabel('Frequency', fontsize = 12)
plt.legend(loc = 'upper left', fontsize = 13)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
